# %% [markdown]
# # Lift 1 Research Notebook Index
#
# This index contains no duplicated research logic. Open the project notebooks below inside the appropriate environment.
#
# 1. [01 — Data State Research](research_notebooks/01_data_state_research.ipynb)
# 2. [02 — Auction Mechanism Event Studies](research_notebooks/02_auction_mechanism_event_studies.ipynb)
# 3. [03 — Robustness Go/No-Go](research_notebooks/03_robustness_go_no_go.ipynb)

# %%
from __future__ import annotations

from systematic_futures.config.markets import reference_market_definitions

[root.root for root in reference_market_definitions()]

# %% [markdown]
# Notebook 1 is the only operational Lift 1 research notebook. Notebooks 2 and 3 are documentation-only boundaries for later authorized work.
