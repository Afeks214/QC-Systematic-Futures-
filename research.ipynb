# %% [markdown]
# # Futures Measurement Client
#
# This notebook is for descriptive measurement only. No orders, forecasts, targets, or portfolio logic are permitted.

# %%
from systematic_futures.config.markets import all_market_definitions
from systematic_futures.config.measurement import MEASUREMENT_CLOCK_POLICY

{
    "roots": tuple(market.root for market in all_market_definitions()),
    "fast_bar_minutes": MEASUREMENT_CLOCK_POLICY.fast_bar_minutes,
    "medium_bar_minutes": MEASUREMENT_CLOCK_POLICY.medium_state_bar_minutes,
}

# %% [markdown]
# Business logic remains in importable modules. The notebook contains no persisted outputs and performs no trading action.
